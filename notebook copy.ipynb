# %%
import dash
from dash.dependencies import Output, Input, State
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import numpy as np
import pandas as pd
import datetime

#some random values
a = datetime.datetime.today()
numdays = 100
dateList = []
for x in range (0, numdays):
    dateList.append(a - datetime.timedelta(days = x))
xy = [dateList,np.random.rand(100)]

df = pd.DataFrame(data=xy[1],columns=["y"],index=xy[0])

app = dash.Dash()

app.title = 'Random'

dataS = [dict(
    x = df.index,
    y = df['y'],
    name = 'OL meter',
    mode = 'lines'
)]

def uptLayout(yaxRang):
    return 


layoutS = go.Layout(
    title="OL Meter",
    xaxis=dict(
        rangeslider_visible=True,
        rangeselector=dict(
            buttons=list([
                dict(count=0, label="1m", step="month", stepmode="backward"),
                dict(count=6, label="6m", step="month", stepmode="backward"),
                dict(count=1, label="YTD", step="year", stepmode="todate"),
                dict(count=1, label="1y", step="year", stepmode="backward"),
                dict(count=5, label="5y", step="year", stepmode="backward"),
                dict(step="all")
            ])
        )
    ),
    yaxis=dict(range=[0,2])
)


app.layout = html.Div(
    html.Div([
        html.H1(children='Random nums'),
        html.Div(children='''
            Rand rand rand.
        '''),
        
        dcc.Input(
            id='input-y',
            placeholder='Insert y value',
            type='number',
            value='',
        ),
        html.Div(id='result'),
        
        dcc.Graph(id='RandGraph',figure=dict(data=dataS,layout=layoutS))
    ])
)

@app.callback(
    Output('RandGraph','figure'),
    [Input('RandGraph','relayoutData')],[State('RandGraph', 'figure')]
)
def update_result(relOut,Fig):
    ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
    ymax = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].max()
    newLayout = go.Layout(
        title="OL Meter",
        xaxis=dict(
            rangeslider_visible=True,
            rangeselector=dict(
                buttons=list([
                    dict(count=0, label="1m", step="month", stepmode="backward"),
                    dict(count=6, label="6m", step="month", stepmode="backward"),
                    dict(count=1, label="YTD", step="year", stepmode="todate"),
                    dict(count=1, label="1y", step="year", stepmode="backward"),
                    dict(count=5, label="5y", step="year", stepmode="backward"),
                    dict(step="all")
                ])
            ),
            range=relOut['xaxis.range']
        ),
        yaxis=dict(range=[ymin,ymax])
    )
    
    
    Fig['layout']=newLayout
    return Fig



if __name__ == '__main__':
    app.run_server(debug=False,port=8060)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8060/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# [2024-07-12 00:22:03,880] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# TypeError: 'NoneType' object is not subscriptable
# [2024-07-12 00:22:04,122] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:07,026] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:08,183] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:08,850] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:09,228] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:09,565] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:10,038] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:13,049] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:13,389] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:13,842] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:14,311] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:15,066] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:25,593] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:25,947] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:26,186] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:26,433] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:30,437] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:30,751] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:31,003] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:31,326] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:31,825] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:32,109] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:32,405] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
# [2024-07-12 00:22:32,748] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\dash.py", line 1310, in dispatch
#     ctx.run(
#   File "c:\Users\plmar\anaconda3\Lib\site-packages\dash\_callback.py", line 442, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\plmar\AppData\Local\Temp\ipykernel_88144\1684445943.py", line 78, in update_result
#     ymin = df.loc[relOut['xaxis.range'][1]:relOut['xaxis.range'][0],'y'].min()
#                   ~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'xaxis.range'
